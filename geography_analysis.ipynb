# %% [markdown]
# # Can LLMs geocode addresses?
#
# This notebook contains the experiment described in this post: LLMs are better at geography than you think.
#
# If you'd like to run it from scratch, you will need API keys from both [OpenAI](https://openai.com/api/) and [Geocode Earth](https://geocode.earth/). You can obtain data and cut your own samples from the [National Address Database](https://www.transportation.gov/gis/national-address-database). I sliced a sample using the following command, with NAD_r19.txt being the [CSV downloaded here](https://nationaladdressdata.s3.amazonaws.com/NAD_r19_TXT.zip):
#
# ```
# gshuf -n 250 TXT/NAD_r19.txt >> ~/apps/llm-geography-test/data/nadsample.txt
# ```
#
# If you have questions, feel free to reach out: **chase@localangle.co**

# %% [markdown]
# ## Setup
#
# This section sets up imports, variables and helper functions.

# %%
# Import required libraries
import pandas as pd
import openai
import time
import json
import requests
from IPython.core.magic import register_cell_magic
from IPython import get_ipython

# Set to true if you want to run the geocoder and LLM guesser again
REPROCESS_DATA = False

OPENAI_API_KEY = ''
OPENAI_MODEL = 'gpt-4o'
openai.api_key = OPENAI_API_KEY

GEOCODE_EARTH_API_KEY = ''

# Helper function to skip cells if a condition is met

@register_cell_magic
def skip_if(line, cell):
    if eval(line):
        return
    get_ipython().run_cell(cell)

# %%
########## HELPER FUNCTIONS ##########

# LLM functions

def _clean_json_response(response_text: str) -> str:
    """Clean and extract JSON from LLM response."""
    # Remove markdown code blocks if present
    if response_text.startswith('```json'):
        response_text = response_text[7:]
    if response_text.endswith('```'):
        response_text = response_text[:-3]
    
    # Remove any leading/trailing whitespace
    response_text = response_text.strip()
    
    return response_text

def call_llm(prompt: str, model: str = OPENAI_MODEL, force_json: bool = True, max_retries: int = 3) -> str:
    """
    Call OpenAI's LLM with the given prompt and model with exponential backoff retries.
    
    Args:
        prompt (str): The prompt to send to the LLM
        model (str): The model name (e.g., 'gpt-4o-mini', 'gpt-4o')
        force_json (bool): Whether to force JSON output (default: True)
        max_retries (int): Maximum number of retry attempts (default: 3)
        
    Returns:
        str: The LLM response text
        
    Raises:
        ValueError: If no API key is available or prompt is empty
        Exception: If the LLM call fails after all retries
    """
    if not prompt:
        raise ValueError("Prompt cannot be empty")
    
    if not model:
        raise ValueError("Model cannot be empty")
    
    if not OPENAI_API_KEY:
        raise ValueError("OpenAI API key not found. Please set OPENAI_API_KEY.")
    
    # Set system message based on force_json parameter
    if force_json:
        system_message = "You are a helpful assistant that returns only structured JSON output."
    else:
        system_message = "You are a helpful assistant that returns direct, concise responses without markdown formatting or explanations."
    
    for attempt in range(max_retries):
        try:
            response = openai.chat.completions.create(
                model=model,
                messages=[
                    {"role": "system", "content": system_message},
                    {"role": "user", "content": prompt}
                ],
                temperature=0.0
            )
            response_text = response.choices[0].message.content.strip()
            return _clean_json_response(response_text)
        except Exception as e:
            if attempt < max_retries - 1:
                wait_time = 2 ** attempt  # Exponential backoff: 1s, 2s, 4s
                print(f"OpenAI API call failed (attempt {attempt + 1}/{max_retries}): {str(e)}")
                print(f"Retrying in {wait_time} seconds...")
                time.sleep(wait_time)
            else:
                raise Exception(f"OpenAI API call failed after {max_retries} attempts: {str(e)}")

# Geocoding functions

def geocode_city(city: str, state: str):
    """
    Geocode a location using Pelias search API.
    
    Args:
        address (str): Location text to geocode
        
    Returns:
        dict: Coordinates and metadata, or None if geocoding fails
    """
    try:
        url = "https://api.geocode.earth/v1/search/structured"
        params = {
            "locality": city,
            "region": state,
            "size": 1  # Just get the best result
        }
        
        if GEOCODE_EARTH_API_KEY:
            params["api_key"] = GEOCODE_EARTH_API_KEY
            
        response = requests.get(url, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()
        
        if data.get("features") and len(data["features"]) > 0:
            feature = data["features"][0]
            coords = feature.get("geometry", {}).get("coordinates", [])
            
            if len(coords) >= 2:
                return {
                    "latitude": coords[1],
                    "longitude": coords[0],
                    "confidence": feature.get("properties", {}).get("confidence", 0),
                    "label": feature.get("properties", {}).get("label", "")
                }
        
        return None
        
    except Exception as e:
        print(f"Geocoding failed for '{address}': {str(e)}")
        return None

# %% [markdown]
# ## Load and process the data
#
# This section contains logic for loading and processing the NAD data file, as well as geocoding the city centers and addresses within.
#
# The results from the experiment described in the post persisted in the file `nadsample_processed.txt`.
#
# Set the `REPROCESS_DATA` variable to `True` if you would like to delete that file and rerun the geographic processing on both fronts. This might be useful if you choose to cut your own sample.

# %%
# Load the CSV data into a pandas DataFrame
# Specify Zip_Code as string to preserve leading zeros and handle non-numeric values
df = pd.read_csv('data/nadsample.txt', dtype={'Zip_Code': str})

# %%
# Create a full address string by joining the specified fields
address_fields = ['AddNo_Full', 'StNam_Full', 'Post_City', 'State', 'Zip_Code']

df['address_str'] = df[['AddNo_Full', 'StNam_Full']].apply(
    lambda row: f"{row['AddNo_Full']} {row['StNam_Full']}",
    axis=1
)

df['city_state'] = df[['Post_City', 'State']].apply(
    lambda row: f"{row['Post_City']}, {row['State']}",
    axis=1
)

df['address_full'] = df[['address_str', 'city_state', 'Zip_Code']].apply(
    lambda row: f"{row['address_str']} {row['city_state']}, {row['Zip_Code']}",
    axis=1
)

# Filter out records where Post_City is None or "Not stated"
df_filtered = df[(df['Post_City'].notna()) & (df['Post_City'] != 'Not stated')]

# Rename Latitude and Longitude to lowercase
df_filtered = df_filtered.rename(columns={
    'Latitude': 'latitude',
    'Longitude': 'longitude',
    'Zip_Code': 'zip'})

# Display the filtered address_str field along with coordinates
address_data = df_filtered[['address_str', 'city_state', 'zip', 'address_full', 'latitude', 'longitude']]

# %%
print("Dataset Shape:", address_data.shape)
address_data.head(50)
# Out:
# Dataset Shape: (188, 6)
#                          address_str            city_state    zip  \
# 0                 504 TRENTON Street          HARRIMAN, TN  37748
# 1                     22 Nagel Drive           Buffalo, NY  14225
# 2                 5836 Hubbard Drive         Rockville, MD  20852
# 4         2891 LAKE SHORE Road South            DENVER, NC  28037
# 5               7544 South 2020 East             OGDEN, UT  84405
# 6                4626 Parkside Drive         Baltimore, MD  21206
# 8                4162 WINDTREE Drive   SIGNAL MOUNTAIN, TN  37377
# 10   2225 East County Road 740 North      NORTH VERNON, IN  47265
# 11              4250 SARATOGA Avenue     Downers Grove, IL  60515
# 12             1453 WATER LILY Drive              LITT, TX  75068
# 14                 700 SUNRISE Court         ARLINGTON, TX    NaN
# 16              10531 CAMELOT Street       WESTCHESTER, IL  60154
# 18          108 1/2 North 3RD Street         Bardstown, KY  40004
# 19              3033 RUSTLEWIND Lane     GRAND PRAIRIE, TX    NaN
# 20            13533 Highway 11 North        COTTONDALE, AL  35453
# 22    7854 ALEXANDER PROMENADE Place           RALEIGH, NC  27617
# 23        22 Avenue at Port Imperial     West New York, NJ  07093
# 25                8402 Oak Meade Way            Jessup, MD  20794
# 27                   102 SHADY GROVE        GEORGETOWN, TX  78633
# 28             602 FLINT RIDGE Trail        GEORGETOWN, TX  78628
# 29          732 South BERKLEY Avenue          Elmhurst, IL  60126
# 30         4101 102 West ILES Avenue       SPRINGFIELD, IL  62711
# 34               102 North ALEX Road   WEST CARROLLTON, OH  45449
# 35             423 SIXTH Street West            IRVING, TX  75060
# 36                 2223 Norden Court      INDIANAPOLIS, IN  46219
# 37             3102 Chesapeake Drive          Dumfries, VA  22026
# 38            11790 SPRINGFIELD Pike        CINCINNATI, OH  45246
# 40         136 13TH Street Northwest           HICKORY, NC  28601
# 41             520 Little Buck Creek        BARNES MTN, KY  40336
# 42       3019 South Carpenter Street          APPLETON, WI  54915
# 43                44592 CARNS Avenue        SPRINGVIEW, NE    NaN
# 44                3836 OLYMPIA Drive           RALEIGH, NC  27603
# 45                 1611 PEARL Avenue    JEFFERSON CITY, TN  37760
# 48              24243 Kylemore Drive             Aldie, VA  20105
# 49   5365 West County Road 760 North            ORLAND, IN  46776
# 50              134 Louis Bowen Road      Jacksonville, AR  72076
# 51           203 West Hinkley Street         Brookland, AR  72417
# 52                324 Fairmount Road       Long Valley, NJ  07853
# 53                 1445 GREENS Court  Glendale Heights, IL  60139
# 54                 14 HASTINGS Court        ST CHARLES, MO  63301
# 56              520 East Plum Street          Vineland, NJ  08360
# 57  9927 CERRO LARGO Place Northwest       ALBUQUERQUE, NM  87114
# 58           11421 North Oriole Lane            MEQUON, WI  53092
# 59              3120 KNOB CREEK Road          COLUMBIA, TN  38401
# 61             715 North WEST Street             Olney, IL  62450
# 62                     1132 Broadway            Elmira, NY  14904
# 63                   32 BLUEBIRD Way      INDIAN POINT, MO  65616
# 66         1324 County Road 740 East      JOHNSONVILLE, IL  62850
# 67                    6558 JACK Cove        MILLINGTON, TN  38053
# 68               11007 NORTHAM Drive           TOMBALL, TX  77375
#
#                                          address_full   latitude   longitude
# 0              504 TRENTON Street HARRIMAN, TN, 37748  35.934435  -84.549231
# 1                   22 Nagel Drive Buffalo, NY, 14225  42.919926  -78.746159
# 2             5836 Hubbard Drive Rockville, MD, 20852  39.054235  -77.119597
# 4        2891 LAKE SHORE Road South DENVER, NC, 28037  35.497915  -80.981462
# 5               7544 South 2020 East OGDEN, UT, 84405  41.129919 -111.926519
# 6            4626 Parkside Drive Baltimore, MD, 21206  39.323020  -76.558190
# 8      4162 WINDTREE Drive SIGNAL MOUNTAIN, TN, 37377  35.176604  -85.343036
# 10  2225 East County Road 740 North NORTH VERNON, ...  39.093891  -85.569821
# 11      4250 SARATOGA Avenue Downers Grove, IL, 60515  41.809848  -88.016703
# 12              1453 WATER LILY Drive LITT, TX, 75068  33.181223  -96.914244
# 14               700 SUNRISE Court ARLINGTON, TX, nan  32.782823  -97.101521
# 16        10531 CAMELOT Street WESTCHESTER, IL, 60154  41.858400  -87.885731
# 18      108 1/2 North 3RD Street Bardstown, KY, 40004  37.809852  -85.466824
# 19        3033 RUSTLEWIND Lane GRAND PRAIRIE, TX, nan  32.696767  -97.038359
# 20       13533 Highway 11 North COTTONDALE, AL, 35453  33.168642  -87.401638
# 22  7854 ALEXANDER PROMENADE Place RALEIGH, NC, 27617  35.912873  -78.780560
# 23  22 Avenue at Port Imperial West New York, NJ, ...  40.781812  -74.006623
# 25               8402 Oak Meade Way Jessup, MD, 20794  39.166340  -76.795821
# 27              102 SHADY GROVE GEORGETOWN, TX, 78633  30.712097  -97.757768
# 28        602 FLINT RIDGE Trail GEORGETOWN, TX, 78628  30.656196  -97.793359
# 29       732 South BERKLEY Avenue Elmhurst, IL, 60126  41.877319  -87.954723
# 30   4101 102 West ILES Avenue SPRINGFIELD, IL, 62711  39.771832  -89.731052
# 34     102 North ALEX Road WEST CARROLLTON, OH, 45449  39.677381  -84.242091
# 35            423 SIXTH Street West IRVING, TX, 75060  32.809650  -96.951429
# 36          2223 Norden Court INDIANAPOLIS, IN, 46219  39.799095  -86.057887
# 37          3102 Chesapeake Drive Dumfries, VA, 22026  38.584961  -77.305414
# 38       11790 SPRINGFIELD Pike CINCINNATI, OH, 45246  39.291194  -84.484900
# 40       136 13TH Street Northwest HICKORY, NC, 28601  35.734429  -81.360302
# 41        520 Little Buck Creek BARNES MTN, KY, 40336  37.639414  -83.881533
# 42    3019 South Carpenter Street APPLETON, WI, 54915  44.233420  -88.393009
# 43             44592 CARNS Avenue SPRINGVIEW, NE, nan  42.781123  -99.553426
# 44              3836 OLYMPIA Drive RALEIGH, NC, 27603  35.737785  -78.661032
# 45        1611 PEARL Avenue JEFFERSON CITY, TN, 37760  36.118891  -83.488696
# 48              24243 Kylemore Drive Aldie, VA, 20105  38.946330  -77.575111
# 49  5365 West County Road 760 North ORLAND, IN, 46776  41.755074  -85.097599
# 50       134 Louis Bowen Road Jacksonville, AR, 72076  34.837093  -92.025036
# 51       203 West Hinkley Street Brookland, AR, 72417  35.900293  -90.583765
# 52          324 Fairmount Road Long Valley, NJ, 07853  40.746543  -74.769538
# 53      1445 GREENS Court Glendale Heights, IL, 60139  41.912128  -88.097415
# 54            14 HASTINGS Court ST CHARLES, MO, 63301  38.813054  -90.516440
# 56           520 East Plum Street Vineland, NJ, 08360  39.488413  -75.024542
# 57  9927 CERRO LARGO Place Northwest ALBUQUERQUE, ...  35.193122 -106.747163
# 58          11421 North Oriole Lane MEQUON, WI, 53092  43.225899  -87.933978
# 59           3120 KNOB CREEK Road COLUMBIA, TN, 38401  35.770203  -87.045571
# 61             715 North WEST Street Olney, IL, 62450  38.742458  -88.095283
# 62                    1132 Broadway Elmira, NY, 14904  42.058788  -76.818750
# 63            32 BLUEBIRD Way INDIAN POINT, MO, 65616  36.661501  -93.349847
# 66  1324 County Road 740 East JOHNSONVILLE, IL, 62850  38.449992  -88.563425
# 67               6558 JACK Cove MILLINGTON, TN, 38053  35.304933  -89.915967
# 68             11007 NORTHAM Drive TOMBALL, TX, 77375  30.037252  -95.585948

# %% [markdown]
# ## Geocode addresses and persist coordinates
#
# The first part of this section geocodes city centers as a baseline. The second attempts to estimate each address' lat/lon with GPT-5. The results of this are persisted in `data/nadsample_geocoded.txt`.

# %%
# %%skip_if REPROCESS_DATA == False
#
# # Geocode city centers using the geocode_address function (FIXED VERSION)
# print("Geocoding city centers...")
#
# # Make a proper copy to avoid SettingWithCopyWarning
# address_data = address_data.copy()
#
# # Initialize new columns
# address_data['city_lat'] = None
# address_data['city_lon'] = None
# address_data['city_confidence'] = None
#
# # Geocode each unique city_state
# unique_cities = address_data['city_state'].unique()
# city_geocodes = {}
#
# for i, city_state in enumerate(unique_cities):
#     print(f"Geocoding {city_state} ({i+1}/{len(unique_cities)})...")
#
#     city, state = city_state.split(', ')
#     city = city.strip()
#     state = state.strip()
#
#     result = geocode_city(city, state)
#     if result:
#         city_geocodes[city_state] = {
#             'city_lat': result['latitude'],
#             'city_lon': result['longitude'],
#             'city_confidence': result['confidence']
#         }
#         print(f"  → {result['latitude']:.4f}, {result['longitude']:.4f} (confidence: {result['confidence']})")
#     else:
#         print(f"  → Failed to geocode {city}")
#         city_geocodes[city_state] = {
#             'city_lat': None,
#             'city_lon': None,
#             'city_confidence': None
#         }
#     time.sleep(0.5)
#
# # Apply geocoded results to the dataframe
# for city_state, coords in city_geocodes.items():
#     mask = address_data['city_state'] == city_state
#     # Apply to each matching row individually to avoid pandas issues
#     for idx in address_data[mask].index:
#         address_data.loc[idx, 'city_lat'] = coords['city_lat']
#         address_data.loc[idx, 'city_lon'] = coords['city_lon']
#         address_data.loc[idx, 'city_confidence'] = coords['city_confidence']
#
# print(address_data.head(5))
#
# # Save the geocoded dataframe to CSV
# output_file = 'data/nadsample_geocode.txt'
# address_data.to_csv(output_file, index=False)
# print(f"\nGeocoded data saved to {output_file}")
#
# # Show summary
# print(f"\nSummary:")
# print(f"Total addresses: {len(address_data)}")
# print(f"Unique cities: {len(unique_cities)}")
# successful_geocodes = sum(1 for coords in city_geocodes.values() if coords['city_lat'] is not None)
# print(f"Successfully geocoded: {successful_geocodes}/{len(unique_cities)} cities")
# Out:
# Geocoding city centers...
# Geocoding HARRIMAN, TN (1/178)...
#   → 35.9335, -84.5503 (confidence: 1)
# Geocoding Buffalo, NY (2/178)...
#   → 42.8908, -78.8529 (confidence: 1)
# Geocoding Rockville, MD (3/178)...
#   → 39.0800, -77.1585 (confidence: 1)
# Geocoding DENVER, NC (4/178)...
#   → 35.5355, -81.0337 (confidence: 1)
# Geocoding OGDEN, UT (5/178)...
#   → 41.2319, -111.9624 (confidence: 1)
# Geocoding Baltimore, MD (6/178)...
#   → 39.3197, -76.6495 (confidence: 1)
# Geocoding SIGNAL MOUNTAIN, TN (7/178)...
#   → 35.1406, -85.3394 (confidence: 1)
# Geocoding NORTH VERNON, IN (8/178)...
#   → 39.0036, -85.6312 (confidence: 1)
# Geocoding Downers Grove, IL (9/178)...
#   → 41.8014, -88.0073 (confidence: 1)
# Geocoding LITT, TX (10/178)...
#   → 31.0310, -98.3263 (confidence: 0.3)
# Geocoding ARLINGTON, TX (11/178)...
#   → 32.6857, -97.1029 (confidence: 1)
# Geocoding WESTCHESTER, IL (12/178)...
#   → 41.8483, -87.8890 (confidence: 1)
# Geocoding Bardstown, KY (13/178)...
#   → 37.8198, -85.4611 (confidence: 1)
# Geocoding GRAND PRAIRIE, TX (14/178)...
#   → 32.6770, -97.0235 (confidence: 1)
# Geocoding COTTONDALE, AL (15/178)...
#   → 13.3139, 123.5639 (confidence: 0.3)
# Geocoding RALEIGH, NC (16/178)...
#   → 35.7955, -78.6444 (confidence: 1)
# Geocoding West New York, NJ (17/178)...
#   → 40.7857, -74.0091 (confidence: 1)
# Geocoding Jessup, MD (18/178)...
#   → 39.1493, -76.7711 (confidence: 1)
# Geocoding GEORGETOWN, TX (19/178)...
#   → 30.6425, -97.6743 (confidence: 1)
# Geocoding Elmhurst, IL (20/178)...
#   → 41.8997, -87.9428 (confidence: 1)
# Geocoding SPRINGFIELD, IL (21/178)...
#   → 39.7973, -89.6455 (confidence: 1)
# Geocoding WEST CARROLLTON, OH (22/178)...
#   → 39.6688, -84.2537 (confidence: 1)
# Geocoding IRVING, TX (23/178)...
#   → 32.8601, -96.9789 (confidence: 1)
# Geocoding INDIANAPOLIS, IN (24/178)...
#   → 39.7859, -86.1434 (confidence: 1)
# Geocoding Dumfries, VA (25/178)...
#   → 38.5686, -77.3236 (confidence: 1)
# Geocoding CINCINNATI, OH (26/178)...
#   → 39.1476, -84.5441 (confidence: 1)
# Geocoding HICKORY, NC (27/178)...
#   → 35.7430, -81.3290 (confidence: 1)
# Geocoding BARNES MTN, KY (28/178)...
#   → 37.6968, -84.9241 (confidence: 0.3)
# Geocoding APPLETON, WI (29/178)...
#   → 44.2643, -88.3945 (confidence: 1)
# Geocoding SPRINGVIEW, NE (30/178)...
#   → 42.8240, -99.7487 (confidence: 1)
# Geocoding JEFFERSON CITY, TN (31/178)...
#   → 36.1247, -83.4889 (confidence: 1)
# Geocoding Aldie, VA (32/178)...
#   → 37.7309, -78.3767 (confidence: 0.3)
# Geocoding ORLAND, IN (33/178)...
#   → 41.7299, -85.1716 (confidence: 1)
# Geocoding Jacksonville, AR (34/178)...
#   → 34.8830, -92.1265 (confidence: 1)
# Geocoding Brookland, AR (35/178)...
#   → 35.9017, -90.5816 (confidence: 1)
# Geocoding Long Valley, NJ (36/178)...
#   → 40.7883, -74.7914 (confidence: 1)
# Geocoding Glendale Heights, IL (37/178)...
#   → 41.9205, -88.0899 (confidence: 1)
# Geocoding ST CHARLES, MO (38/178)...
#   → 38.7983, -90.5040 (confidence: 1)
# Geocoding Vineland, NJ (39/178)...
#   → 39.4643, -74.9996 (confidence: 1)
# Geocoding ALBUQUERQUE, NM (40/178)...
#   → 35.1287, -106.5791 (confidence: 1)
# Geocoding MEQUON, WI (41/178)...
#   → 43.2471, -88.0201 (confidence: 1)
# Geocoding COLUMBIA, TN (42/178)...
#   → 35.6082, -87.0471 (confidence: 1)
# Geocoding Olney, IL (43/178)...
#   → 38.7311, -88.0867 (confidence: 1)
# Geocoding Elmira, NY (44/178)...
#   → 42.0952, -76.8092 (confidence: 1)
# Geocoding INDIAN POINT, MO (45/178)...
#   → 36.6432, -93.3433 (confidence: 1)
# Geocoding JOHNSONVILLE, IL (46/178)...
#   → 38.5199, -88.5382 (confidence: 1)
# Geocoding MILLINGTON, TN (47/178)...
#   → 35.3414, -89.8920 (confidence: 1)
# Geocoding TOMBALL, TX (48/178)...
#   → 30.0950, -95.6185 (confidence: 1)
# Geocoding STATESVILLE, NC (49/178)...
#   → 35.7847, -80.8860 (confidence: 1)
# Geocoding Akron, OH (50/178)...
#   → 41.0780, -81.5383 (confidence: 1)
# Geocoding COOKEVILLE, TN (51/178)...
#   → 36.1569, -85.5006 (confidence: 1)
# Geocoding Bay Shore, NY (52/178)...
#   → 40.7338, -73.2475 (confidence: 1)
# Geocoding ROCK ISLAND, IL (53/178)...
#   → 41.4883, -90.5883 (confidence: 1)
# Geocoding Thurmont, MD (54/178)...
#   → 39.6236, -77.4110 (confidence: 1)
# Geocoding Bellingham, WA (55/178)...
#   → 48.7642, -122.4682 (confidence: 1)
# Geocoding CHARLOTTE, NC (56/178)...
#   → 35.1953, -80.8171 (confidence: 1)
# Geocoding CANONSBURG, PA (57/178)...
#   → 40.2597, -80.1868 (confidence: 1)
# Geocoding Clifton Park, NY (58/178)...
#   → 42.8598, -73.8248 (confidence: 1)
# Geocoding Hot Springs National Park, AR (59/178)...
#   → 34.5317, -93.0638 (confidence: 1)
# Geocoding Austin, TX (60/178)...
#   → 30.2223, -97.8365 (confidence: 1)
# Geocoding BOLINGBROOK, IL (61/178)...
#   → 41.6913, -88.0906 (confidence: 1)
# Geocoding HOUSTON, TX (62/178)...
#   → 29.7848, -95.3614 (confidence: 1)
# Geocoding BASTROP, TX (63/178)...
#   → 30.1172, -97.3129 (confidence: 1)
# Geocoding MANHATTAN, IL (64/178)...
#   → 41.4465, -87.9733 (confidence: 1)
# Geocoding SAN ANTONIO, TX (65/178)...
#   → 29.3750, -98.5886 (confidence: 1)
# Geocoding MAGNOLIA, TX (66/178)...
#   → 30.2216, -95.7435 (confidence: 1)
# Geocoding PARK HILL, OK (67/178)...
#   → 35.8515, -94.9499 (confidence: 1)
# Geocoding BELMOND, IA (68/178)...
#   → 42.8471, -93.6067 (confidence: 1)
# Geocoding FUQUAY VARINA, NC (69/178)...
#   → 35.5901, -78.7978 (confidence: 1)
# Geocoding TAYLORSVILLE, NC (70/178)...
#   → 35.9157, -81.1827 (confidence: 1)
# Geocoding LOS ALAMOS, NM (71/178)...
#   → 35.8923, -106.2853 (confidence: 1)
# Geocoding NELSONVILLE, OH (72/178)...
#   → 39.4575, -82.2185 (confidence: 1)
# Geocoding SHELBYVILLE, IN (73/178)...
#   → 39.5167, -85.7794 (confidence: 1)
# Geocoding Medford, NJ (74/178)...
#   → 39.8549, -74.8120 (confidence: 1)
# Geocoding HENDERSONVILLE, NC (75/178)...
#   → 35.3162, -82.4652 (confidence: 1)
# Geocoding Earleville, MD (76/178)...
#   → 40.5080, -3.7677 (confidence: 0.3)
# Geocoding Westampton, NJ (77/178)...
#   → 40.0092, -74.8362 (confidence: 1)
# Geocoding MORRISON, MO (78/178)...
#   → 38.6719, -91.6342 (confidence: 1)
# Geocoding WASHINGTON, PA (79/178)...
#   → 40.1746, -80.2486 (confidence: 1)
# Geocoding NEW BERN, NC (80/178)...
#   → 35.1219, -77.0795 (confidence: 1)
# Geocoding WILMINGTON, VT (81/178)...
#   → 42.8711, -72.8680 (confidence: 1)
# Geocoding BELVIDERE, IL (82/178)...
#   → 42.2561, -88.8397 (confidence: 1)
# Geocoding BENBROOK, TX (83/178)...
#   → 32.6639, -97.4659 (confidence: 1)
# Geocoding NORTH WEBSTER, IN (84/178)...
#   → 41.3211, -85.6971 (confidence: 1)
# Geocoding COLUMBUS, IN (85/178)...
#   → 39.2208, -85.9072 (confidence: 1)
# Geocoding Rockbridge Baths, VA (86/178)...
#   → 37.7309, -78.3767 (confidence: 0.3)
# Geocoding INOLA, OK (87/178)...
#   → 36.1172, -95.5528 (confidence: 1)
# Geocoding Dayton, NJ (88/178)...
#   → 40.3814, -74.5135 (confidence: 1)
# Geocoding EUCHA, OK (89/178)...
#   → 36.3892, -94.8517 (confidence: 1)
# Geocoding Daviston, AL (90/178)...
#   → 33.0557, -85.6371 (confidence: 1)
# Geocoding Kingman, AZ (91/178)...
#   → 35.2090, -114.0233 (confidence: 1)
# Geocoding Kensington, MD (92/178)...
#   → 39.0408, -77.0726 (confidence: 1)
# Geocoding WASHINGTON, NC (93/178)...
#   → 35.5514, -77.0475 (confidence: 1)
# Geocoding SAINT GEORGE, UT (94/178)...
#   → 37.0503, -113.5599 (confidence: 1)
# Geocoding Niagara Falls, NY (95/178)...
#   → 43.0924, -79.0249 (confidence: 1)
# Geocoding Woodbourne, NY (96/178)...
#   → 41.7598, -74.5940 (confidence: 1)
# Geocoding Spokane Valley, WA (97/178)...
#   → 47.6592, -117.2416 (confidence: 1)
# Geocoding Norristown, PA (98/178)...
#   → 40.1231, -75.3402 (confidence: 1)
# Geocoding WILMINGTON, OH (99/178)...
#   → 39.4484, -83.8255 (confidence: 1)
# Geocoding Deer Park, NY (100/178)...
#   → 40.7627, -73.3155 (confidence: 1)
# Geocoding TROY, AL (101/178)...
#   → 31.7982, -85.9688 (confidence: 1)
# Geocoding Prescott Valley, AZ (102/178)...
#   → 34.6142, -112.3171 (confidence: 1)
# Geocoding ANTLERS, OK (103/178)...
#   → 34.2335, -95.6171 (confidence: 1)
# Geocoding McDonough, NY (104/178)...
#   → 42.4984, -75.7680 (confidence: 1)
# Geocoding West Memphis, AR (105/178)...
#   → 35.1514, -90.1853 (confidence: 1)
# Geocoding GASTONIA, NC (106/178)...
#   → 35.2613, -81.2012 (confidence: 1)
# Geocoding CANTON, NC (107/178)...
#   → 35.5345, -82.8388 (confidence: 1)
# Geocoding Sayville, NY (108/178)...
#   → 40.7503, -73.0844 (confidence: 1)
# Geocoding CENTERVILLE, UT (109/178)...
#   → 40.9294, -111.8852 (confidence: 1)
# Geocoding MASONTOWN, WV (110/178)...
#   → 39.5523, -79.7987 (confidence: 1)
# Geocoding Spotswood, NJ (111/178)...
#   → 40.3964, -74.3905 (confidence: 1)
# Geocoding APEX, NC (112/178)...
#   → 35.7304, -78.8527 (confidence: 1)
# Geocoding Morris Plains, NJ (113/178)...
#   → 40.8349, -74.4789 (confidence: 1)
# Geocoding NEW ALBANY, IN (114/178)...
#   → 38.3069, -85.8209 (confidence: 1)
# Geocoding ROCK HILL, SC (115/178)...
#   → 34.9335, -81.0199 (confidence: 1)
# Geocoding HOWARD, OH (116/178)...
#   → 40.4096, -82.3280 (confidence: 1)
# Geocoding Fife, WA (117/178)...
#   → 47.2333, -122.3525 (confidence: 1)
# Geocoding Ragland, AL (118/178)...
#   → 33.7561, -86.1331 (confidence: 1)
# Geocoding CHESTERFIELD, MO (119/178)...
#   → 38.6529, -90.5643 (confidence: 1)
# Geocoding CHANNELVIEW, TX (120/178)...
#   → 29.7923, -95.1300 (confidence: 1)
# Geocoding MANCHESTER, TN (121/178)...
#   → 35.4644, -86.0776 (confidence: 1)
# Geocoding ARLINGTON, WA (122/178)...
#   → 48.1619, -122.1535 (confidence: 1)
# Geocoding RIPLEY, TN (123/178)...
#   → 35.7439, -89.5353 (confidence: 1)
# Geocoding FERGUSON, NC (124/178)...
#   → 36.0857, -81.3684 (confidence: 1)
# Geocoding Owego, NY (125/178)...
#   → 42.1015, -76.2643 (confidence: 1)
# Geocoding LAREDO, TX (126/178)...
#   → 27.5355, -99.4838 (confidence: 1)
# Geocoding Staten Island, NY (127/178)...
#   → 40.5899, -74.1518 (confidence: 1)
# Geocoding Dundalk, MD (128/178)...
#   → 39.2748, -76.5008 (confidence: 1)
# Geocoding Chenango Forks, NY (129/178)...
#   → 42.2356, -75.8482 (confidence: 1)
# Geocoding BLOOMINGTON, IN (130/178)...
#   → 39.1647, -86.5207 (confidence: 1)
# Geocoding Van Buren, AR (131/178)...
#   → 35.4465, -94.3490 (confidence: 1)
# Geocoding Pennsauken, NJ (132/178)...
#   → 39.9562, -75.0580 (confidence: 1)
# Geocoding Richmond Hill, NY (133/178)...
#   → 43.4088, -74.8716 (confidence: 0.3)
# Geocoding SACRAMENTO, CA (134/178)...
#   → 38.5787, -121.4668 (confidence: 1)
# Geocoding Rogers, AR (135/178)...
#   → 36.3170, -94.1504 (confidence: 1)
# Geocoding Nobleboro, ME (136/178)...
#   → 44.0795, -69.4851 (confidence: 1)
# Geocoding DOYLESTOWN, OH (137/178)...
#   → 40.9680, -81.6937 (confidence: 1)
# Geocoding Port Jefferson Station, NY (138/178)...
#   → 40.9234, -73.0646 (confidence: 1)
# Geocoding Clancy, MT (139/178)...
#   → 46.4641, -111.9921 (confidence: 1)
# Geocoding PERRYSBURG, OH (140/178)...
#   → 41.5394, -83.6448 (confidence: 1)
# Geocoding TROUP, TX (141/178)...
#   → 32.1441, -95.1239 (confidence: 1)
# Geocoding PAOLA, KS (142/178)...
#   → 38.5751, -94.8652 (confidence: 1)
# Geocoding MILLS RIVER, NC (143/178)...
#   → 35.3845, -82.5755 (confidence: 1)
# Geocoding NILES, IL (144/178)...
#   → 42.0298, -87.8085 (confidence: 1)
# Geocoding SOUTHINGTON, OH (145/178)...
#   → 41.3084, -80.9559 (confidence: 1)
# Geocoding UNIVERSITY PARK, TX (146/178)...
#   → 32.8543, -96.7920 (confidence: 1)
# Geocoding EAU CLAIRE, WI (147/178)...
#   → 44.8184, -91.5023 (confidence: 1)
# Geocoding Lake Havasu City, AZ (148/178)...
#   → 34.5007, -114.3125 (confidence: 1)
# Geocoding Ridgewood, NJ (149/178)...
#   → 40.9826, -74.1093 (confidence: 1)
# Geocoding SPRINGFIELD, MO (150/178)...
#   → 37.1973, -93.2807 (confidence: 1)
# Geocoding Harrisonburg, VA (151/178)...
#   → 38.4377, -78.8703 (confidence: 1)
# Geocoding Esperance, NY (152/178)...
#   → 42.7650, -74.2581 (confidence: 1)
# Geocoding FAYETTEVILLE, NC (153/178)...
#   → 35.0892, -79.0202 (confidence: 1)
# Geocoding CALVERT, AL (154/178)...
#   → 31.1539, -88.0128 (confidence: 1)
# Geocoding OLYMPIA FIELDS, IL (155/178)...
#   → 41.5182, -87.7032 (confidence: 1)
# Geocoding WEST END, NC (156/178)...
#   → 35.2399, -79.5675 (confidence: 1)
# Geocoding Mechanicsville, VA (157/178)...
#   → 37.6291, -77.3657 (confidence: 1)
# Geocoding Casper, WY (158/178)...
#   → 42.8443, -106.3117 (confidence: 1)
# Geocoding CANTON, OH (159/178)...
#   → 40.8036, -81.3751 (confidence: 1)
# Geocoding GREENVILLE, TX (160/178)...
#   → 33.1084, -96.1154 (confidence: 1)
# Geocoding MORRIS, IL (161/178)...
#   → 41.3697, -88.4334 (confidence: 1)
# Geocoding EATON, OH (162/178)...
#   → 39.7467, -84.6361 (confidence: 1)
# Geocoding NEW BRAUNFELS, TX (163/178)...
#   → 29.6947, -98.1161 (confidence: 1)
# Geocoding Dundee, IL (164/178)...
#   → 42.1063, -88.3107 (confidence: 1)
# Geocoding GARLAND, TX (165/178)...
#   → 32.9077, -96.6403 (confidence: 1)
# Geocoding HUTCHINSON, KS (166/178)...
#   → 38.0664, -97.9190 (confidence: 1)
# Geocoding FAIR OAKS, CA (167/178)...
#   → 38.6485, -121.2407 (confidence: 1)
# Geocoding Columbia Falls, MT (168/178)...
#   → 48.3680, -114.1897 (confidence: 1)
# Geocoding Ithaca, NY (169/178)...
#   → 42.4434, -76.5055 (confidence: 1)
# Geocoding CASTLE HAYNE, NC (170/178)...
#   → 34.3616, -77.9113 (confidence: 1)
# Geocoding OSAGE BEACH, MO (171/178)...
#   → 38.1332, -92.6440 (confidence: 1)
# Geocoding ORRUM, NC (172/178)...
#   → 34.4668, -79.0088 (confidence: 1)
# Geocoding BEULAH, ND (173/178)...
#   → 47.2652, -101.7793 (confidence: 1)
# Geocoding ABILENE, KS (174/178)...
#   → 38.9231, -97.2151 (confidence: 1)
# Geocoding Delaplane, VA (175/178)...
#   → 37.7309, -78.3767 (confidence: 0.3)
# Geocoding Libby, MT (176/178)...
#   → 48.3879, -115.5543 (confidence: 1)
# Geocoding Eagar, AZ (177/178)...
#   → 34.1042, -109.2961 (confidence: 1)
# Geocoding TABOR CITY, NC (178/178)...
#   → 34.1497, -78.8741 (confidence: 1)
#                   address_str     city_state    zip  \
# 0          504 TRENTON Street   HARRIMAN, TN  37748
# 1              22 Nagel Drive    Buffalo, NY  14225
# 2          5836 Hubbard Drive  Rockville, MD  20852
# 4  2891 LAKE SHORE Road South     DENVER, NC  28037
# 5        7544 South 2020 East      OGDEN, UT  84405
#
#                                    address_full   latitude   longitude  \
# 0        504 TRENTON Street HARRIMAN, TN, 37748  35.934435  -84.549231
# 1             22 Nagel Drive Buffalo, NY, 14225  42.919926  -78.746159
# 2       5836 Hubbard Drive Rockville, MD, 20852  39.054235  -77.119597
# 4  2891 LAKE SHORE Road South DENVER, NC, 28037  35.497915  -80.981462
# 5         7544 South 2020 East OGDEN, UT, 84405  41.129919 -111.926519
#
#     city_lat    city_lon city_confidence
# 0  35.933509  -84.550277               1
# 1  42.890831  -78.852918               1
# 2  39.080026  -77.158493               1
# 4  35.535494  -81.033744               1
# 5  41.231877 -111.962366               1
#
# Geocoded data saved to data/nadsample_geocode.txt
#
# Summary:
# Total addresses: 188
# Unique cities: 178
# Successfully geocoded: 178/178 cities

# %%
prompt = f"""Please estimate the latitude and longitude of the following address.
Use your knowledge of the city, its road systems and general conventions of geography
to make your estimate. Be as accurate and precise as possible.

Results should be returned as a JSON object with three attributes, latitude, longitude
and confidence.

Latitude and longitude should be in decimal degrees. Confidence should be a number
between 0 and 1 and should reflect your confidence in the accuracy of the estimate.

Here is the address to estimate:

"""

# %%
# %%skip_if REPROCESS_DATA == False
#
# # Use LLM to geocode addresses
# print("Geocoding addresses with LLM...")
#
# # Initialize new columns for LLM results
# address_data['llm_lat'] = None
# address_data['llm_lon'] = None
# address_data['llm_confidence'] = None
#
# # Process addresses
# for i, (idx, row) in enumerate(address_data.iterrows()):
#     address = row['address_full']
#     print(f"LLM Geocoding {address} ({i+1}/{len(address_data)})...")
#
#     try:
#         # Create the full prompt with the address
#         full_prompt = prompt + address
#
#         # Call the LLM
#         response = call_llm(full_prompt)
#
#         # Parse the JSON response
#         result = json.loads(response)
#
#         # Extract coordinates and confidence
#         address_data.loc[idx, 'llm_lat'] = result.get('latitude')
#         address_data.loc[idx, 'llm_lon'] = result.get('longitude')
#         address_data.loc[idx, 'llm_confidence'] = result.get('confidence')
#
#         print(f"  → {result.get('latitude')}, {result.get('longitude')} (confidence: {result.get('confidence')})")
#
#     except Exception as e:
#         print(f"  → Failed to geocode with LLM: {str(e)}")
#         address_data.loc[idx, 'llm_lat'] = None
#         address_data.loc[idx, 'llm_lon'] = None
#         address_data.loc[idx, 'llm_confidence'] = None
#
#     # Add a small delay to avoid rate limiting
#     time.sleep(1)
#
# # Save the updated dataframe
# output_file = 'data/nadsample_geocode.txt'
# address_data.to_csv(output_file, index=False)
# print(f"\nLLM geocoded data saved to {output_file}")
#
# # Show summary
# successful_llm_geocodes = address_data['llm_lat'].notna().sum()
# print(f"\nLLM Geocoding Summary:")
# print(f"Total addresses processed: {len(address_data)}")
# print(f"Successfully geocoded: {successful_llm_geocodes}/{len(address_data)} addresses")
# Out:
# Geocoding addresses with LLM...
# LLM Geocoding 504 TRENTON Street HARRIMAN, TN, 37748 (1/188)...
#   → 35.9336, -84.5522 (confidence: 0.9)
# LLM Geocoding 22 Nagel Drive Buffalo, NY, 14225 (2/188)...
#   → 42.9295, -78.7548 (confidence: 0.9)
# LLM Geocoding 5836 Hubbard Drive Rockville, MD, 20852 (3/188)...
#   → 39.0522, -77.1208 (confidence: 0.9)
# LLM Geocoding 2891 LAKE SHORE Road South DENVER, NC, 28037 (4/188)...
#   → 35.5053, -81.0043 (confidence: 0.9)
# LLM Geocoding 7544 South 2020 East OGDEN, UT, 84405 (5/188)...
#   → 41.1396, -111.9484 (confidence: 0.9)
# LLM Geocoding 4626 Parkside Drive Baltimore, MD, 21206 (6/188)...
#   → 39.3445, -76.5568 (confidence: 0.9)
# LLM Geocoding 4162 WINDTREE Drive SIGNAL MOUNTAIN, TN, 37377 (7/188)...
#   → 35.1333, -85.3433 (confidence: 0.9)
# LLM Geocoding 2225 East County Road 740 North NORTH VERNON, IN, 47265 (8/188)...
#   → 39.0105, -85.6053 (confidence: 0.8)
# LLM Geocoding 4250 SARATOGA Avenue Downers Grove, IL, 60515 (9/188)...
#   → 41.8164, -88.0112 (confidence: 0.9)
# LLM Geocoding 1453 WATER LILY Drive LITT, TX, 75068 (10/188)...
#   → 33.1663, -96.9375 (confidence: 0.9)
# LLM Geocoding 700 SUNRISE Court ARLINGTON, TX, nan (11/188)...
#   → 32.705, -97.1228 (confidence: 0.8)
# LLM Geocoding 10531 CAMELOT Street WESTCHESTER, IL, 60154 (12/188)...
#   → 41.8515, -87.8834 (confidence: 0.9)
# LLM Geocoding 108 1/2 North 3RD Street Bardstown, KY, 40004 (13/188)...
#   → 37.8106, -85.4669 (confidence: 0.9)
# LLM Geocoding 3033 RUSTLEWIND Lane GRAND PRAIRIE, TX, nan (14/188)...
#   → 32.6848, -97.0373 (confidence: 0.9)
# LLM Geocoding 13533 Highway 11 North COTTONDALE, AL, 35453 (15/188)...
#   → 33.2045, -87.4548 (confidence: 0.8)
# LLM Geocoding 7854 ALEXANDER PROMENADE Place RALEIGH, NC, 27617 (16/188)...
#   → 35.9095, -78.7528 (confidence: 0.9)
# LLM Geocoding 22 Avenue at Port Imperial West New York, NJ, 07093 (17/188)...
#   → 40.787, -74.01 (confidence: 0.9)
# LLM Geocoding 8402 Oak Meade Way Jessup, MD, 20794 (18/188)...
#   → 39.1445, -76.8058 (confidence: 0.9)
# LLM Geocoding 102 SHADY GROVE GEORGETOWN, TX, 78633 (19/188)...
#   → 30.7153, -97.7114 (confidence: 0.9)
# LLM Geocoding 602 FLINT RIDGE Trail GEORGETOWN, TX, 78628 (20/188)...
#   → 30.6545, -97.7326 (confidence: 0.9)
# LLM Geocoding 732 South BERKLEY Avenue Elmhurst, IL, 60126 (21/188)...
#   → 41.8875, -87.9431 (confidence: 0.9)
# LLM Geocoding 4101 102 West ILES Avenue SPRINGFIELD, IL, 62711 (22/188)...
#   → 39.7575, -89.6985 (confidence: 0.9)
# LLM Geocoding 102 North ALEX Road WEST CARROLLTON, OH, 45449 (23/188)...
#   → 39.6753, -84.2527 (confidence: 0.9)
# LLM Geocoding 423 SIXTH Street West IRVING, TX, 75060 (24/188)...
#   → 32.8122, -96.9472 (confidence: 0.9)
# LLM Geocoding 2223 Norden Court INDIANAPOLIS, IN, 46219 (25/188)...
#   → 39.7934, -86.0486 (confidence: 0.9)
# LLM Geocoding 3102 Chesapeake Drive Dumfries, VA, 22026 (26/188)...
#   → 38.5805, -77.3248 (confidence: 0.9)
# LLM Geocoding 11790 SPRINGFIELD Pike CINCINNATI, OH, 45246 (27/188)...
#   → 39.2833, -84.4858 (confidence: 0.9)
# LLM Geocoding 136 13TH Street Northwest HICKORY, NC, 28601 (28/188)...
#   → 35.7419, -81.3412 (confidence: 0.9)
# LLM Geocoding 520 Little Buck Creek BARNES MTN, KY, 40336 (29/188)...
#   → 37.6983, -83.9654 (confidence: 0.7)
# LLM Geocoding 3019 South Carpenter Street APPLETON, WI, 54915 (30/188)...
#   → 44.2448, -88.3895 (confidence: 0.9)
# LLM Geocoding 44592 CARNS Avenue SPRINGVIEW, NE, nan (31/188)...
#   → 42.8261, -99.7487 (confidence: 0.8)
# LLM Geocoding 3836 OLYMPIA Drive RALEIGH, NC, 27603 (32/188)...
#   → 35.7376, -78.6645 (confidence: 0.9)
# LLM Geocoding 1611 PEARL Avenue JEFFERSON CITY, TN, 37760 (33/188)...
#   → 36.1225, -83.4921 (confidence: 0.8)
# LLM Geocoding 24243 Kylemore Drive Aldie, VA, 20105 (34/188)...
#   → 38.9645, -77.5458 (confidence: 0.9)
# LLM Geocoding 5365 West County Road 760 North ORLAND, IN, 46776 (35/188)...
#   → 41.7315, -85.1786 (confidence: 0.9)
# LLM Geocoding 134 Louis Bowen Road Jacksonville, AR, 72076 (36/188)...
#   → 34.8703, -92.1105 (confidence: 0.9)
# LLM Geocoding 203 West Hinkley Street Brookland, AR, 72417 (37/188)...
#   → 35.0725, -90.5823 (confidence: 0.8)
# LLM Geocoding 324 Fairmount Road Long Valley, NJ, 07853 (38/188)...
#   → 40.7852, -74.7802 (confidence: 0.9)
# LLM Geocoding 1445 GREENS Court Glendale Heights, IL, 60139 (39/188)...
#   → 41.9186, -88.0895 (confidence: 0.9)
# LLM Geocoding 14 HASTINGS Court ST CHARLES, MO, 63301 (40/188)...
#   → 38.8083, -90.5157 (confidence: 0.9)
# LLM Geocoding 520 East Plum Street Vineland, NJ, 08360 (41/188)...
#   → 39.4862, -75.0196 (confidence: 0.9)
# LLM Geocoding 9927 CERRO LARGO Place Northwest ALBUQUERQUE, NM, 87114 (42/188)...
#   → 35.2045, -106.6783 (confidence: 0.9)
# LLM Geocoding 11421 North Oriole Lane MEQUON, WI, 53092 (43/188)...
#   → 43.2365, -87.9515 (confidence: 0.9)
# LLM Geocoding 3120 KNOB CREEK Road COLUMBIA, TN, 38401 (44/188)...
#   → 35.6153, -87.0353 (confidence: 0.8)
# LLM Geocoding 715 North WEST Street Olney, IL, 62450 (45/188)...
#   → 38.7345, -88.0856 (confidence: 0.9)
# LLM Geocoding 1132 Broadway Elmira, NY, 14904 (46/188)...
#   → 42.0814, -76.7983 (confidence: 0.9)
# LLM Geocoding 32 BLUEBIRD Way INDIAN POINT, MO, 65616 (47/188)...
#   → 36.6365, -93.3433 (confidence: 0.9)
# LLM Geocoding 1324 County Road 740 East JOHNSONVILLE, IL, 62850 (48/188)...
#   → 38.4412, -88.4189 (confidence: 0.8)
# LLM Geocoding 6558 JACK Cove MILLINGTON, TN, 38053 (49/188)...
#   → 35.3417, -89.8975 (confidence: 0.9)
# LLM Geocoding 11007 NORTHAM Drive TOMBALL, TX, 77375 (50/188)...
#   → 30.0975, -95.6103 (confidence: 0.9)
# LLM Geocoding 148 LONG POND Drive STATESVILLE, NC, 28625 (51/188)...
#   → 35.805, -80.872 (confidence: 0.8)
# LLM Geocoding 389 VALINDA Place Akron, OH, 44304 (52/188)...
#   → 41.0814, -81.519 (confidence: 0.8)
# LLM Geocoding 2146 FOSTER Circle COOKEVILLE, TN, 38501 (53/188)...
#   → 36.1628, -85.5016 (confidence: 0.8)
# LLM Geocoding 1088 Manor Lane Bay Shore, NY, 11706 (54/188)...
#   → 40.7395, -73.2521 (confidence: 0.9)
# LLM Geocoding 2640 27TH Street ROCK ISLAND, IL, 61201 (55/188)...
#   → 41.4805, -90.5631 (confidence: 0.9)
# LLM Geocoding 107 Water Street Thurmont, MD, 21788 (56/188)...
#   → 39.6232, -77.4105 (confidence: 0.9)
# LLM Geocoding 2037 West BAKERVIEW Road Bellingham, WA, 98226 (57/188)...
#   → 48.7905, -122.5053 (confidence: 0.9)
# LLM Geocoding 613 SILVERSMITH Lane CHARLOTTE, NC, 28270 (58/188)...
#   → 35.1095, -80.7645 (confidence: 0.9)
# LLM Geocoding 308 CRICKETWOOD Court CANONSBURG, PA, 15317 (59/188)...
#   → 40.2737, -80.1784 (confidence: 0.9)
# LLM Geocoding 1400 Crescent Vischer Ferry Road Clifton Park, NY, 12065 (60/188)...
#   → 42.8205, -73.8156 (confidence: 0.9)
# LLM Geocoding 213 Shady Hills Street Hot Springs National Park, AR, 71901 (61/188)...
#   → 34.5037, -93.0552 (confidence: 0.8)
# LLM Geocoding 3710 RHYNES GATE Way RALEIGH, NC, 27606 (62/188)...
#   → 35.7376, -78.7351 (confidence: 0.9)
# LLM Geocoding 6906 RIVERTON Drive Austin, TX, 78729 (63/188)...
#   → 30.4515, -97.7542 (confidence: 0.9)
# LLM Geocoding 713 ADAMS Street BOLINGBROOK, IL, 60440 (64/188)...
#   → 41.6986, -88.0684 (confidence: 0.9)
# LLM Geocoding 6423 BUFORD Street HOUSTON, TX, 77023 (65/188)...
#   → 29.7245, -95.3167 (confidence: 0.9)
# LLM Geocoding 257 LOWER RED ROCK Road BASTROP, TX, 78602 (66/188)...
#   → 30.1105, -97.3098 (confidence: 0.8)
# LLM Geocoding 16056 West BENCK Street MANHATTAN, IL, 60442 (67/188)...
#   → 41.4225, -87.9856 (confidence: 0.9)
# LLM Geocoding 12818 FAIRVIEW FARMS SAN ANTONIO, TX, nan (68/188)...
#   → 29.5567, -98.6123 (confidence: 0.8)
# LLM Geocoding 30201 SECRET RIVER Court MAGNOLIA, TX, 77354 (69/188)...
#   → 30.2094, -95.7508 (confidence: 0.9)
# LLM Geocoding 26340 Highway 82 PARK HILL, OK, 74451 (70/188)...
#   → 35.8575, -94.9736 (confidence: 0.8)
# LLM Geocoding 904 5TH Avenue Northeast BELMOND, IA, nan (71/188)...
#   → 42.8475, -93.6136 (confidence: 0.9)
# LLM Geocoding 89 DAYBREAK Way FUQUAY VARINA, NC, 27526 (72/188)...
#   → 35.5895, -78.8 (confidence: 0.9)
# LLM Geocoding 214 CARLTON HOWELL Drive TAYLORSVILLE, NC, 28681 (73/188)...
#   → 35.9212, -81.1766 (confidence: 0.9)
# LLM Geocoding 3706 1 GOLD Street LOS ALAMOS, NM, 87544 (74/188)...
#   → 35.8825, -106.3031 (confidence: 0.9)
# LLM Geocoding 1000 East CANAL Street NELSONVILLE, OH, 45764 (75/188)...
#   → 39.4581, -82.2301 (confidence: 0.9)
# LLM Geocoding 109 3rd Street SHELBYVILLE, IN, 46176 (76/188)...
#   → 39.5281, -85.7767 (confidence: 0.9)
# LLM Geocoding 3 Severn Court Medford, NJ, 08055 (77/188)...
#   → 39.8995, -74.8233 (confidence: 0.9)
# LLM Geocoding 415 LINWOOD POND Road HENDERSONVILLE, NC, 28739 (78/188)...
#   → 35.3187, -82.4968 (confidence: 0.9)
# LLM Geocoding 729 Fingerboard Schoolhouse Road Earleville, MD, 21919 (79/188)...
#   → 39.4135, -75.9012 (confidence: 0.9)
# LLM Geocoding 31 Augusta Drive Westampton, NJ, 08060 (80/188)...
#   → 40.0115, -74.8173 (confidence: 0.9)
# LLM Geocoding 3656 Highway N MORRISON, MO, 65061 (81/188)...
#   → 38.6765, -91.6352 (confidence: 0.8)
# LLM Geocoding 39 WEAVER RUN Road WASHINGTON, PA, 15301 (82/188)...
#   → 40.1703, -80.2462 (confidence: 0.8)
# LLM Geocoding 4014 COPPERFIELD Drive NEW BERN, NC, 28562 (83/188)...
#   → 35.1085, -77.0998 (confidence: 0.9)
# LLM Geocoding 305 RAY HILL Road WILMINGTON, VT, 05363 (84/188)...
#   → 42.8703, -72.8728 (confidence: 0.9)
# LLM Geocoding 312 VAN BUREN BELVIDERE, IL, 61008 (85/188)...
#   → 42.2576, -88.8443 (confidence: 0.9)
# LLM Geocoding 9821 RAVENSWAY Drive BENBROOK, TX, nan (86/188)...
#   → 32.6732, -97.4606 (confidence: 0.9)
# LLM Geocoding 146 Ems W25 Lane NORTH WEBSTER, IN, 46555 (87/188)...
#   → 41.3317, -85.6923 (confidence: 0.9)
# LLM Geocoding 4821 Pine Ridge COLUMBUS, IN, 47201 (88/188)...
#   → 39.2014, -85.9214 (confidence: 0.8)
# LLM Geocoding 271 Brownsburg Road Rockbridge Baths, VA, 24473 (89/188)...
#   → 37.8995, -79.3728 (confidence: 0.8)
# LLM Geocoding 16055 East RANCHETTE Road INOLA, OK, 74036 (90/188)...
#   → 36.1532, -95.5108 (confidence: 0.8)
# LLM Geocoding 354 Georges Road Dayton, NJ, 08810 (91/188)...
#   → 40.3795, -74.5143 (confidence: 0.9)
# LLM Geocoding 1819 COUNTY ROAD 359 EUCHA, OK, 74342 (92/188)...
#   → 36.4295, -94.8983 (confidence: 0.8)
# LLM Geocoding 22499 Highway 22 East Daviston, AL, 36256 (93/188)...
#   → 33.0365, -85.6842 (confidence: 0.8)
# LLM Geocoding 8692 North Ironwood Drive Kingman, AZ, 86401 (94/188)...
#   → 35.4095, -113.8783 (confidence: 0.8)
# LLM Geocoding 9814 Connecticut Avenue Kensington, MD, 20895 (95/188)...
#   → 39.0165, -77.0763 (confidence: 0.9)
# LLM Geocoding 501 West 7TH Street WASHINGTON, NC, 27889 (96/188)...
#   → 35.5484, -77.0563 (confidence: 0.9)
# LLM Geocoding 4455 South IRONWOOD Drive SAINT GEORGE, UT, 84790 (97/188)...
#   → 37.0365, -113.5669 (confidence: 0.9)
# LLM Geocoding 3302 Hyde Park Boulevard Niagara Falls, NY, 14305 (98/188)...
#   → 43.1045, -79.0377 (confidence: 0.9)
# LLM Geocoding 272 Benton Hollow Road Woodbourne, NY, 12788 (99/188)...
#   → 41.7853, -74.5989 (confidence: 0.9)
# LLM Geocoding 13310 East Mission Avenue Spokane Valley, WA, 99216 (100/188)...
#   → 47.6653, -117.2225 (confidence: 0.95)
# LLM Geocoding 662 Stanbridge Street Norristown, PA, 19401 (101/188)...
#   → 40.1262, -75.3414 (confidence: 0.9)
# LLM Geocoding 657 KATHRYN Drive WILMINGTON, OH, 45177 (102/188)...
#   → 39.4455, -83.8281 (confidence: 0.9)
# LLM Geocoding 294 West 19th Street Deer Park, NY, 11729 (103/188)...
#   → 40.7598, -73.3295 (confidence: 0.9)
# LLM Geocoding 393 County Road 5523 TROY, AL, 36081 (104/188)...
#   → 31.8088, -85.9677 (confidence: 0.8)
# LLM Geocoding 10970 East Lady Bug Place Prescott Valley, AZ, 86315 (105/188)...
#   → 34.6545, -112.3183 (confidence: 0.9)
# LLM Geocoding 196245 North 4210 Road ANTLERS, OK, 74523 (106/188)...
#   → 34.2335, -95.6208 (confidence: 0.8)
# LLM Geocoding 1868 State Route 220 McDonough, NY, 13801 (107/188)...
#   → 42.5295, -75.7063 (confidence: 0.9)
# LLM Geocoding 2307 Wheeler Avenue West Memphis, AR, 72301 (108/188)...
#   → 35.1503, -90.1845 (confidence: 0.9)
# LLM Geocoding 365 North NEW HOPE Road GASTONIA, NC, 28054 (109/188)...
#   → 35.2735, -81.1456 (confidence: 0.9)
# LLM Geocoding 45 CRESTVIEW Street CANTON, NC, 28716 (110/188)...
#   → 35.5325, -82.8371 (confidence: 0.9)
# LLM Geocoding 279 Lakeland Avenue Sayville, NY, 11782 (111/188)...
#   → 40.7462, -73.0815 (confidence: 0.9)
# LLM Geocoding 180 East ROLLING HILLS Drive CENTERVILLE, UT, 84014 (112/188)...
#   → 40.9182, -111.8722 (confidence: 0.9)
# LLM Geocoding 801 ROHR Road MASONTOWN, WV, 26542 (113/188)...
#   → 39.5512, -79.8103 (confidence: 0.8)
# LLM Geocoding 289 Main Street Spotswood, NJ, 08884 (114/188)...
#   → 40.3915, -74.3893 (confidence: 0.9)
# LLM Geocoding 500 JUSTICE HEIGHTS Street APEX, NC, 27502 (115/188)...
#   → 35.7327, -78.8503 (confidence: 0.9)
# LLM Geocoding 2 G Foxwood Drive Morris Plains, NJ, 07950 (116/188)...
#   → 40.8483, -74.4771 (confidence: 0.9)
# LLM Geocoding 1111 Clark Street NEW ALBANY, IN, 47150 (117/188)...
#   → 38.3018, -85.8214 (confidence: 0.9)
# LLM Geocoding 3909 GALLERIA POINTE Circle ROCK HILL, SC, 29730 (118/188)...
#   → 34.9385, -80.9785 (confidence: 0.9)
# LLM Geocoding 92 GREENFIELD Court HOWARD, OH, 43028 (119/188)...
#   → 40.4362, -82.3321 (confidence: 0.9)
# LLM Geocoding 6058 RADIANCE Boulevard East Fife, WA, 98424 (120/188)...
#   → 47.2359, -122.3478 (confidence: 0.9)
# LLM Geocoding 1937 Denas Cove Road Ragland, AL, 35131 (121/188)...
#   → 33.7465, -86.1412 (confidence: 0.8)
# LLM Geocoding 246 HUNDLEY Street MASONTOWN, WV, 26542 (122/188)...
#   → 39.5512, -79.8053 (confidence: 0.9)
# LLM Geocoding 1254 BEAVER CREEK Road CHESTERFIELD, MO, 63017 (123/188)...
#   → 38.6475, -90.5528 (confidence: 0.9)
# LLM Geocoding 15930 MARKET Street CHANNELVIEW, TX, 77530 (124/188)...
#   → 29.7765, -95.1141 (confidence: 0.9)
# LLM Geocoding 46 COUNTRY AIR Lane MANCHESTER, TN, 37355 (125/188)...
#   → 35.4817, -86.0885 (confidence: 0.8)
# LLM Geocoding 246 West 4TH Street ARLINGTON, WA, 98223 (126/188)...
#   → 48.1833, -122.1251 (confidence: 0.9)
# LLM Geocoding 800 BELTON Road RIPLEY, TN, 38063 (127/188)...
#   → 35.7456, -89.5292 (confidence: 0.9)
# LLM Geocoding 282 FALCON RIDGE Lane FERGUSON, NC, 28624 (128/188)...
#   → 36.125, -81.35 (confidence: 0.8)
# LLM Geocoding 67 Erie Street Owego, NY, 13827 (129/188)...
#   → 42.1034, -76.2611 (confidence: 0.9)
# LLM Geocoding 8717 CALVARY Court LAREDO, TX, 78045 (130/188)...
#   → 27.6084, -99.4818 (confidence: 0.9)
# LLM Geocoding 24 Natick Street Staten Island, NY, 10306 (131/188)...
#   → 40.5708, -74.1153 (confidence: 0.9)
# LLM Geocoding 3461 Liberty Parkway Dundalk, MD, 21222 (132/188)...
#   → 39.2675, -76.4958 (confidence: 0.9)
# LLM Geocoding 362 Richards Road Chenango Forks, NY, 13746 (133/188)...
#   → 42.2345, -75.8483 (confidence: 0.9)
# LLM Geocoding 936 West Moravec Way BLOOMINGTON, IN, 47404 (134/188)...
#   → 39.1653, -86.5264 (confidence: 0.9)
# LLM Geocoding 18 Vista Hills Boulevard Van Buren, AR, 72956 (135/188)...
#   → 35.4515, -94.3483 (confidence: 0.9)
# LLM Geocoding 3218 45th Street Pennsauken, NJ, 08110 (136/188)...
#   → 39.9645, -75.0582 (confidence: 0.9)
# LLM Geocoding 86 ""-""64 108 Street Richmond Hill, NY, 11418 (137/188)...
#   → 40.6987, -73.8352 (confidence: 0.8)
# LLM Geocoding 345 East RIVERSIDE Drive SAINT GEORGE, UT, 84790 (138/188)...
#   → 37.0875, -113.5584 (confidence: 0.9)
# LLM Geocoding 3145 PALMER Street SACRAMENTO, CA, 95815 (139/188)...
#   → 38.6119, -121.4423 (confidence: 0.9)
# LLM Geocoding 905 East Linden Place Rogers, AR, 72756 (140/188)...
#   → 36.3375, -94.1158 (confidence: 0.9)
# LLM Geocoding 37 Sunset Drive Nobleboro, ME, 04555 (141/188)...
#   → 44.0815, -69.5056 (confidence: 0.8)
# LLM Geocoding 12581 ORCHARD Street DOYLESTOWN, OH, 44230 (142/188)...
#   → 40.9703, -81.6951 (confidence: 0.9)
# LLM Geocoding 1090 Route 112 Port Jefferson Station, NY, 11776 (143/188)...
#   → 40.9223, -73.0484 (confidence: 0.9)
# LLM Geocoding 20 Forest Park Drive Clancy, MT, 59634 (144/188)...
#   → 46.5125, -111.985 (confidence: 0.8)
# LLM Geocoding 829 TURNBURY Lane PERRYSBURG, OH, 43551 (145/188)...
#   → 41.5372, -83.6266 (confidence: 0.9)
# LLM Geocoding 1953 COUNTY ROAD 4701 TROUP, TX, 75789 (146/188)...
#   → 32.1445, -95.1213 (confidence: 0.8)
# LLM Geocoding 26765 West 327TH Street PAOLA, KS, 66071 (147/188)...
#   → 38.5825, -94.8786 (confidence: 0.9)
# LLM Geocoding 187 PENLEE Way MILLS RIVER, NC, 28759 (148/188)...
#   → 35.3855, -82.5607 (confidence: 0.9)
# LLM Geocoding 7737 North NORDICA Avenue NILES, IL, 60714 (149/188)...
#   → 42.0218, -87.8101 (confidence: 0.9)
# LLM Geocoding 18757 BRACKEN Drive SAN ANTONIO, TX, nan (150/188)...
#   → 29.6113, -98.4513 (confidence: 0.8)
# LLM Geocoding 2862 BARCLAY MESSERLY Road Northwest SOUTHINGTON, OH, 44470 (151/188)...
#   → 41.2653, -80.8742 (confidence: 0.9)
# LLM Geocoding 3525 CARUTH Boulevard UNIVERSITY PARK, TX, 75225 (152/188)...
#   → 32.8553, -96.7905 (confidence: 0.9)
# LLM Geocoding 6128 Macbeth Drive Baltimore, MD, 21239 (153/188)...
#   → 39.3635, -76.5885 (confidence: 0.9)
# LLM Geocoding 1003 Doty Street EAU CLAIRE, WI, 54701 (154/188)...
#   → 44.7984, -91.4882 (confidence: 0.9)
# LLM Geocoding 1745 Avalon Bay Lake Havasu City, AZ, 86404 (155/188)...
#   → 34.5133, -114.325 (confidence: 0.8)
# LLM Geocoding 226 Gateway Road Ridgewood, NJ, 07450 (156/188)...
#   → 40.9812, -74.1165 (confidence: 0.9)
# LLM Geocoding 2162 East RIDGEWOOD Drive SPRINGFIELD, MO, 65804 (157/188)...
#   → 37.1591, -93.2643 (confidence: 0.9)
# LLM Geocoding 322 6Th Street Harrisonburg, VA, 22802 (158/188)...
#   → 38.4562, -78.8651 (confidence: 0.9)
# LLM Geocoding 110 Miller Lane Esperance, NY, 12066 (159/188)...
#   → 42.5995, -74.2918 (confidence: 0.8)
# LLM Geocoding 7795 TRAPPERS Road FAYETTEVILLE, NC, 28311 (160/188)...
#   → 35.1735, -78.8803 (confidence: 0.8)
# LLM Geocoding 752 Bayou Circle CALVERT, AL, nan (161/188)...
#   → 31.0954, -88.0103 (confidence: 0.8)
# LLM Geocoding 20816 GREENWOOD Drive OLYMPIA FIELDS, IL, 60461 (162/188)...
#   → 41.5189, -87.6845 (confidence: 0.9)
# LLM Geocoding 110 PINECONE Court WEST END, NC, 27376 (163/188)...
#   → 35.2615, -79.5736 (confidence: 0.9)
# LLM Geocoding 7330 Cactus Road Mechanicsville, VA, 23111 (164/188)...
#   → 37.6083, -77.3156 (confidence: 0.8)
# LLM Geocoding 1887 SHUMWAY Avenue Casper, WY, 82601 (165/188)...
#   → 42.8557, -106.3252 (confidence: 0.9)
# LLM Geocoding 3000 14TH Street Northwest CANTON, OH, 44708 (166/188)...
#   → 40.8154, -81.4212 (confidence: 0.9)
# LLM Geocoding 100 DIVISION Street GREENVILLE, TX, 75402 (167/188)...
#   → 33.1384, -96.1108 (confidence: 0.8)
# LLM Geocoding 4715 THOMAS RUSK SAN ANTONIO, TX, nan (168/188)...
#   → 29.4269, -98.4896 (confidence: 0.6)
# LLM Geocoding 627 SPRUCE Street MORRIS, IL, 60450 (169/188)...
#   → 41.3642, -88.4212 (confidence: 0.9)
# LLM Geocoding 829 JUDY Avenue EATON, OH, 45320 (170/188)...
#   → 39.7426, -84.6369 (confidence: 0.9)
# LLM Geocoding 1094 HAPPY HOLLOW Drive NEW BRAUNFELS, TX, nan (171/188)...
#   → 29.7225, -98.1256 (confidence: 0.9)
# LLM Geocoding 624 CANTERFIELD Parkway West Dundee, IL, 60118 (172/188)...
#   → 42.0986, -88.2923 (confidence: 0.9)
# LLM Geocoding 5910 Gladden Drive INDIANAPOLIS, IN, 46220 (173/188)...
#   → 39.8625, -86.0867 (confidence: 0.9)
# LLM Geocoding 2022 TIEHACK Lane GARLAND, TX, 75044 (174/188)...
#   → 32.9725, -96.6417 (confidence: 0.9)
# LLM Geocoding 306 West 29TH Avenue HUTCHINSON, KS, 67502 (175/188)...
#   → 38.0858, -97.9298 (confidence: 0.9)
# LLM Geocoding 7464 FAIRWAY TWO Avenue FAIR OAKS, CA, 95628 (176/188)...
#   → 38.6625, -121.2725 (confidence: 0.9)
# LLM Geocoding 1021 Green Valley Court Columbia Falls, MT, 59912 (177/188)...
#   → 48.3717, -114.1811 (confidence: 0.8)
# LLM Geocoding 715 West Court Street Ithaca, NY, 14850 (178/188)...
#   → 42.4418, -76.5071 (confidence: 0.9)
# LLM Geocoding 2617 OAKLEY Road CASTLE HAYNE, NC, 28429 (179/188)...
#   → 34.3553, -77.9136 (confidence: 0.9)
# LLM Geocoding 3810 STONEY RIDGE Trail CHARLOTTE, NC, 28210 (180/188)...
#   → 35.1295, -80.8458 (confidence: 0.9)
# LLM Geocoding 44 TINY HARBOR Lane OSAGE BEACH, MO, 65065 (181/188)...
#   → 38.1503, -92.6179 (confidence: 0.9)
# LLM Geocoding 4058 ATKINSON Road ORRUM, NC, 28369 (182/188)...
#   → 34.4635, -79.0023 (confidence: 0.8)
# LLM Geocoding 814 Highway 49 BEULAH, ND, 58523 (183/188)...
#   → 47.2633, -101.7771 (confidence: 0.9)
# LLM Geocoding 2232 DEER Road ABILENE, KS, 67410 (184/188)...
#   → 38.9172, -97.2139 (confidence: 0.8)
# LLM Geocoding 2180 Jacksontown Pike Delaplane, VA, 20144 (185/188)...
#   → 38.9181, -77.9136 (confidence: 0.9)
# LLM Geocoding 137 Scenery Road Libby, MT, 59923 (186/188)...
#   → 48.3883, -115.555 (confidence: 0.8)
# LLM Geocoding 373 East 7th Lane Eagar, AZ, 85925 (187/188)...
#   → 34.1083, -109.2928 (confidence: 0.9)
# LLM Geocoding 4310 RAMSEY FORD Road TABOR CITY, NC, 28463 (188/188)...
#   → 34.0915, -78.7642 (confidence: 0.8)
#
# LLM geocoded data saved to data/nadsample_geocode.txt
#
# LLM Geocoding Summary:
# Total addresses processed: 188
# Successfully geocoded: 188/188 addresses

# %% [markdown]
# ## Evaluate results
#
# Here we estimate the error between the ground truth lat/lon pairs (provided in the NAD) with both the city centers and the LLM guesses. We use geodesic distance to calculate our error metrics.

# %%
import numpy as np
from geographiclib.geodesic import Geodesic

def geodesic_dist_m(lat1, lon1, lat2, lon2):
    return Geodesic.WGS84.Inverse(lat1, lon1, lat2, lon2)['s12']  # meters

def mean_geodesic_error_m(lat_true, lon_true, lat_pred, lon_pred):
    d = [geodesic_dist_m(lt, ln, lp, lo)
         for lt, ln, lp, lo in zip(lat_true, lon_true, lat_pred, lon_pred)]
    return float(np.mean(d))

# %%
# Evaluate geocoding performance by calculating geodesic distances
print("Calculating geocoding errors...")

if REPROCESS_DATA == False:
    address_data = pd.read_csv('data/nadsample_geocode.txt')

# Initialize error columns
address_data['city_error_m'] = None
address_data['llm_error_m'] = None

# Calculate errors for each row
for idx, row in address_data.iterrows():
    # Get ground truth coordinates
    gt_lat = row['latitude']
    gt_lon = row['longitude']
    
    # Calculate city center error
    if pd.notna(row['city_lat']) and pd.notna(row['city_lon']):
        city_error = geodesic_dist_m(gt_lat, gt_lon, row['city_lat'], row['city_lon'])
        address_data.loc[idx, 'city_error_m'] = city_error
    else:
        address_data.loc[idx, 'city_error_m'] = None
    
    # Calculate LLM error
    if pd.notna(row['llm_lat']) and pd.notna(row['llm_lon']):
        llm_error = geodesic_dist_m(gt_lat, gt_lon, row['llm_lat'], row['llm_lon'])
        address_data.loc[idx, 'llm_error_m'] = llm_error
    else:
        address_data.loc[idx, 'llm_error_m'] = None

# Calculate summary statistics
city_errors = address_data['city_error_m'].dropna()
llm_errors = address_data['llm_error_m'].dropna()

print(f"\nPerformance Summary:")
print(f"Total addresses: {len(address_data)}")
print(f"City center geocoding results: {len(city_errors)}")
print(f"LLM geocoding results: {len(llm_errors)}")

if len(city_errors) > 0:
    print(f"\nCity Center Geocoding Performance:")
    print(f"  Mean error: {city_errors.mean():.1f} meters ({city_errors.mean()/1609.34:.2f} miles)")
    print(f"  Median error: {city_errors.median():.1f} meters ({city_errors.median()/1609.34:.2f} miles)")
    print(f"  Max error: {city_errors.max():.1f} meters ({city_errors.max()/1609.34:.2f} miles)")

if len(llm_errors) > 0:
    print(f"\nLLM Geocoding Performance:")
    print(f"  Mean error: {llm_errors.mean():.1f} meters ({llm_errors.mean()/1609.34:.2f} miles)")
    print(f"  Median error: {llm_errors.median():.1f} meters ({llm_errors.median()/1609.34:.2f} miles)")
    print(f"  Max error: {llm_errors.max():.1f} meters ({llm_errors.max()/1609.34:.2f} miles)")

# Save the results
output_file = 'data/nadsample_geocode.txt'
address_data.to_csv(output_file, index=False)
print(f"\nResults saved to {output_file}")

# Show a sample of the results
print(f"\nSample results:")
sample_data = address_data[['address_full', 'latitude', 'longitude', 'city_error_m', 'llm_error_m']].head(10)
print(sample_data)
# Out:
# Calculating geocoding errors...
#
# Performance Summary:
# Total addresses: 188
# City center geocoding results: 188
# LLM geocoding results: 188
#
# City Center Geocoding Performance:
#   Mean error: 116808.5 meters (72.58 miles)
#   Median error: 4029.7 meters (2.50 miles)
#   Max error: 13906920.1 meters (8641.38 miles)
#
# LLM Geocoding Performance:
#   Mean error: 4422.6 meters (2.75 miles)
#   Median error: 2316.0 meters (1.44 miles)
#   Max error: 91843.4 meters (57.07 miles)
#
# Results saved to data/nadsample_geocode.txt
#
# Sample results:
#                                          address_full   latitude   longitude  \
# 0              504 TRENTON Street HARRIMAN, TN, 37748  35.934435  -84.549231
# 1                   22 Nagel Drive Buffalo, NY, 14225  42.919926  -78.746159
# 2             5836 Hubbard Drive Rockville, MD, 20852  39.054235  -77.119597
# 4        2891 LAKE SHORE Road South DENVER, NC, 28037  35.497915  -80.981462
# 5               7544 South 2020 East OGDEN, UT, 84405  41.129919 -111.926519
# 6            4626 Parkside Drive Baltimore, MD, 21206  39.323020  -76.558190
# 8      4162 WINDTREE Drive SIGNAL MOUNTAIN, TN, 37377  35.176604  -85.343036
# 10  2225 East County Road 740 North NORTH VERNON, ...  39.093891  -85.569821
# 11      4250 SARATOGA Avenue Downers Grove, IL, 60515  41.809848  -88.016703
# 12              1453 WATER LILY Drive LITT, TX, 75068  33.181223  -96.914244
#
#      city_error_m  llm_error_m
# 0      139.526737   283.469541
# 1     9298.414854  1276.239208
# 2     4419.194116   248.776134
# 4     6314.670789  2228.132387
# 5    11715.876336  2128.681922
# 6     7885.268636  2387.775177
# 8     4010.330493  4804.400565
# 10   11346.414776  9753.857646
# 11    1224.074628   859.460758
# 12  273150.544189  2728.440136

# %% [markdown]
# ## Results
#
# The results in this limited case suggest that LLM guesses, though not especially accurate, provide a latitude and longitude that are closer (as the crow flies) to the ground-truth latitude and longitude for each address than city centers.
#
# The mean error is skewed by some city centers that were located in the completely wrong country, apparently. This is an error by the geocoder that we could certainly fix if we ran it again.
#
# It would also be worth trying GPT-5, which I avoided doing mostly because it's very slow ...
